# %%
import pandas as pd

# %%
df=pd.read_csv('/content/online_retail_II.csv')

# %%
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df.tail()
# Out:
#         Invoice StockCode                      Description  Quantity  \
# 1067366  581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138    BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                          POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID Country
# 1067366  2011-12-09 12:50:00   2.10      12680.0  France
# 1067367  2011-12-09 12:50:00   4.15      12680.0  France
# 1067368  2011-12-09 12:50:00   4.15      12680.0  France
# 1067369  2011-12-09 12:50:00   4.95      12680.0  France
# 1067370  2011-12-09 12:50:00  18.00      12680.0  France

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  object
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 65.1+ MB

# %%
df.describe()
# Out:
#            Quantity         Price    Customer ID
# count  1.067371e+06  1.067371e+06  824364.000000
# mean   9.938898e+00  4.649388e+00   15324.638504
# std    1.727058e+02  1.235531e+02    1697.464450
# min   -8.099500e+04 -5.359436e+04   12346.000000
# 25%    1.000000e+00  1.250000e+00   13975.000000
# 50%    3.000000e+00  2.100000e+00   15255.000000
# 75%    1.000000e+01  4.150000e+00   16797.000000
# max    8.099500e+04  3.897000e+04   18287.000000

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(34335)

# %%
df['Quantity'].nunique()
df['Customer ID'].nunique()
df['Country'].nunique()
# Out:
# 43

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4275
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    235151
# Country             0
# dtype: int64

# %%
df.dropna(subset=['Customer ID'] ,inplace=True)

# %%
df.isna().sum()
# Out:
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# dtype: int64

# %%
df.shape
# Out:
# (797885, 8)

# %%
df['InvoiceDate']=pd.to_datetime(df['InvoiceDate'])

# %%
(df['Quantity'] < 0).sum()
# Out:
# np.int64(18390)

# %%
df = df[df['Quantity'] > 0]

# %%
(df['Quantity'] < 0).sum()
# Out:
# np.int64(0)

# %%
df = df[df['Price'] > 0]

# %%
neg1=(df['Price'] < 0).sum()
neg1
# Out:
# np.int64(0)

# %%
df = df.dropna(subset=['Quantity', 'Price'])

# %%
df[['Quantity', 'Price']].isna().sum()
# Out:
# Quantity    0
# Price       0
# dtype: int64

# %%
df['TotalAmount'] = df['Quantity'] * df['Price']

# %%
df['Month'] = df['InvoiceDate'].dt.month
df['Year'] = df['InvoiceDate'].dt.year

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  TotalAmount  Month  \
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom         83.4     12
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom         81.0     12
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom         81.0     12
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom        100.8     12
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom         30.0     12
#
#    Year
# 0  2009
# 1  2009
# 2  2009
# 3  2009
# 4  2009

# %%
(df['Quantity'] < 0).sum()
(df['Price'] <= 0).sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# TotalAmount    0
# Month          0
# Year           0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Total Revenue

total =df['TotalAmount'].sum()
total
# Out:
# np.float64(17374804.268000003)

# %%
# Total Orders ()

df['Invoice'].nunique()
# Out:
# 36969

# %%
col = df.rename(columns={'Customer ID': 'CustomerID'},inplace=True)

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'CustomerID', 'Country', 'TotalAmount', 'Month', 'Year'],
#       dtype='object')

# %%
df['CustomerID'].nunique()
# Out:
# 5878

# %% [markdown]
# # top 10 descriptions

# %%
top_10_products=df.groupby('Description')['TotalAmount'].sum().sort_values(ascending=False).head(10)
top_10_products
# Out:
# Description
# REGENCY CAKESTAND 3 TIER              277656.25
# WHITE HANGING HEART T-LIGHT HOLDER    247048.01
# PAPER CRAFT , LITTLE BIRDIE           168469.60
# Manual                                151777.67
# JUMBO BAG RED RETROSPOT               134307.44
# POSTAGE                               124648.04
# ASSORTED COLOUR BIRD ORNAMENT         124351.86
# PARTY BUNTING                         103283.38
# MEDIUM CERAMIC TOP STORAGE JAR         81416.73
# PAPER CHAIN KIT 50'S CHRISTMAS         76598.18
# Name: TotalAmount, dtype: float64

# %%
top_10_products.plot(kind='bar')
plt.title("Top 10 Products by Sales")
plt.xlabel("Product Description")
plt.ylim(0, 277656)
plt.ylabel("Total Sales")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # top 10 country most sale

# %%
top_10_country=df.groupby('Country')['TotalAmount'].sum().sort_values(ascending=False).head(10)
top_10_country
# Out:
# Country
# United Kingdom    1.438923e+07
# EIRE              6.165705e+05
# Netherlands       5.540381e+05
# Germany           4.250197e+05
# France            3.487690e+05
# Australia         1.692835e+05
# Spain             1.083325e+05
# Switzerland       1.000619e+05
# Sweden            9.151582e+04
# Denmark           6.858069e+04
# Name: TotalAmount, dtype: float64

# %% [markdown]
# # Monthly Sales Trend

# %%
month_sales_trend=df.groupby('Month')['TotalAmount'].sum()
month_sales_trend
# Out:
# Month
# 1     1123903.982
# 2      950643.876
# 3     1291060.231
# 4     1060356.333
# 5     1275188.530
# 6     1296417.180
# 7     1188699.071
# 8     1246275.640
# 9     1779704.153
# 10    2068754.460
# 11    2322665.632
# 12    1771135.180
# Name: TotalAmount, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.plot(month_sales_trend.index,month_sales_trend.values, marker='o')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.title('Monthly Sales Trend')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Top Customers

# %%
top10_customers=df.groupby('CustomerID')['TotalAmount'].sum().sort_values(ascending=False).head(10)
top10_customers
# Out:
# CustomerID
# 18102.0    580987.04
# 14646.0    528602.52
# 14156.0    313437.62
# 14911.0    291420.81
# 17450.0    244784.25
# 13694.0    195640.69
# 17511.0    172132.87
# 16446.0    168472.50
# 16684.0    147142.77
# 12415.0    144458.37
# Name: TotalAmount, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df[['Quantity','Price','TotalAmount']].corr(), annot=True, cmap='YlGnBu')
plt.show()

# %% [markdown]
# # year trend

# %%
year=df.groupby('Year')['TotalAmount'].sum()
year
# Out:
# Year
# 2009     683504.010
# 2010    8374496.094
# 2011    8316804.164
# Name: TotalAmount, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.pie(year.values,labels=year.index,autopct='%1.1f%%')
plt.title('Year-wise Sales Distribution')
plt.show()

# %%
df['TotalAmount'].describe()
# Out:
# count    779425.000000
# mean         22.291823
# std         227.427075
# min           0.001000
# 25%           4.950000
# 50%          12.480000
# 75%          19.800000
# max      168469.600000
# Name: TotalAmount, dtype: float64

# %%
df.isnull().sum()
# Out:
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# CustomerID     0
# Country        0
# TotalAmount    0
# Month          0
# Year           0
# dtype: int64

# %%
df.to_csv("cleaned_online_retail.csv", index=False)
